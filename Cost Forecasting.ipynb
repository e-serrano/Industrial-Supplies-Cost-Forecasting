# %% [markdown]
# # **DESCRIPTION**
#
# This project consist in a forecasting of cost for different industrial supplies from a company

# %% [markdown]
# # **Project Develop**

# %% [markdown]
# ## *Install Libraries*

# %%
# !pip install pandas
# !pip install numpy
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## *Import Libraries*

# %%
import pandas as pd
import numpy as np
import openpyxl

# %% [markdown]
# ## *Import data*
#
# Import data from an Excel file provided by the company

# %%
df_purchases = pd.read_excel("COMPRAS.xlsx", index_col=0)

# %%
df_purchases.head(10)
# Out:
#      order_date delivery_date                   supplier_name  \
# id
# 5252 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5253 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5589 2013-09-02    2013-09-04           Aceros y Equipos S.L.
# 5590 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
# 5591 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
# 5592 2013-09-18    2013-10-21              OFFICINE SANTAFEDE
# 5502 2013-09-20    2013-10-08  ThyssenKrupp Materials Ibérica
# 5503 2013-09-20    2013-09-24           Aceros y Equipos S.L.
# 5504 2013-09-20    2013-09-27       Empresa Santa Lucía, S.A.
# 5505 2013-09-20    2013-09-27       Empresa Santa Lucía, S.A.
#
#                  supply_reference  unit_value  quantity  total_cost
# id
# 5252  BWN 6"900RTJ ID142,88mm F44     1020.00      50.0     51000.0
# 5253            FORGING ROUND F44     2560.00      25.0     64000.0
# 5589         BRE 76,2MM HAST C276       44.50       1.6        71.2
# 5590                   TP1R 0,5mm      420.60       3.0      1261.8
# 5591      VAR 4.5X2X1.2X1000 A710       19.60       5.0        98.0
# 5592           TPI 4-1/16"X4"2500     5200.00       1.0      5200.0
# 5502            BRE 165 AISI-304L        2.55     112.0       285.6
# 5503              BRE 55 AISI-321        4.70     112.0       526.4
# 5504                   BRE 35  A5       14.60     132.0      1927.2
# 5505              BRE 35 ALLOY400       27.50      91.0      2502.5

# %% [markdown]
# ## *Data Resume*

# %%
df_purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10775 entries, 5252 to 10818
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        10775 non-null  datetime64[ns]
#  1   delivery_date     10420 non-null  datetime64[ns]
#  2   supplier_name     10775 non-null  object
#  3   supply_reference  10775 non-null  object
#  4   unit_value        10775 non-null  float64
#  5   quantity          10775 non-null  float64
#  6   total_cost        10775 non-null  float64
# dtypes: datetime64[ns](2), float64(3), object(2)
# memory usage: 931.5+ KB

# %%
df_purchases.describe()
# Out:
#                           order_date                  delivery_date  \
# count                          10775                          10420
# mean   2019-04-04 08:59:46.969837568  2019-02-21 04:31:00.115163136
# min              2013-05-16 00:00:00            2012-11-30 00:00:00
# 25%              2016-10-03 12:00:00            2016-09-05 00:00:00
# 50%              2019-01-29 00:00:00            2018-11-12 00:00:00
# 75%              2022-01-07 00:00:00            2021-09-07 00:00:00
# max              2024-12-16 00:00:00            2024-12-02 00:00:00
# std                              NaN                            NaN
#
#          unit_value      quantity    total_cost
# count  1.077500e+04  1.077500e+04  1.077500e+04
# mean   1.934475e+04  1.707657e+10  3.927612e+11
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.260000e+00  2.000000e+00  4.800000e+01
# 50%    1.950000e+01  6.000000e+00  1.996128e+02
# 75%    1.000000e+02  3.000000e+01  7.427000e+02
# max    1.000000e+07  1.840000e+14  4.232000e+15
# std    2.905807e+05  1.772594e+12  4.076965e+13

# %% [markdown]
# ## *Data Engineering*

# %% [markdown]
# Columns that do not provide data of interest are eliminated.

# %%
df_purchases = df_purchases.drop(columns=["supplier_order_id","position_supply","supply_id","discount","pending",
                    "deliv_date_1","deliv_quant_1","deliv_note_1",
                    "deliv_date_2","deliv_quant_2","deliv_note_2",
                    "deliv_date_3","deliv_quant_3","deliv_note_3"])
# Out:
#      order_date                   supplier_name             supply_reference  \
# id
# 5252 2013-05-16              OFFICINE SANTAFEDE  BWN 6"900RTJ ID142,88mm F44
# 5253 2013-05-16              OFFICINE SANTAFEDE            FORGING ROUND F44
# 5589 2013-09-02           Aceros y Equipos S.L.         BRE 76,2MM HAST C276
# 5590 2013-09-03  UTILES Y MAQUINAS INDUSTRIALES                   TP1R 0,5mm
# 5591 2013-09-03  UTILES Y MAQUINAS INDUSTRIALES      VAR 4.5X2X1.2X1000 A710
#
#       unit_value delivery_date  quantity
# id
# 5252      1020.0    2013-11-18      50.0
# 5253      2560.0    2013-11-18      25.0
# 5589        44.5    2013-09-04       1.6
# 5590       420.6    2013-09-10       3.0
# 5591        19.6    2013-09-10       5.0

# %% [markdown]
# Change the order of columns in dataframe

# %%
new_column_order = ["order_date", "delivery_date", "supplier_name", "supply_reference","unit_value","quantity"]
df_purchases = df_purchases[new_column_order]
# Out:
#      order_date delivery_date                   supplier_name  \
# id
# 5252 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5253 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5589 2013-09-02    2013-09-04           Aceros y Equipos S.L.
# 5590 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
# 5591 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
#
#                  supply_reference  unit_value  quantity
# id
# 5252  BWN 6"900RTJ ID142,88mm F44      1020.0      50.0
# 5253            FORGING ROUND F44      2560.0      25.0
# 5589         BRE 76,2MM HAST C276        44.5       1.6
# 5590                   TP1R 0,5mm       420.6       3.0
# 5591      VAR 4.5X2X1.2X1000 A710        19.6       5.0

# %% [markdown]
# Creation a new column for calculate the total cost of products

# %%
df_purchases["total_cost"] = df_purchases["unit_value"] * df_purchases["quantity"]
# Out:
#      order_date delivery_date                   supplier_name  \
# id
# 5252 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5253 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5589 2013-09-02    2013-09-04           Aceros y Equipos S.L.
# 5590 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
# 5591 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
#
#                  supply_reference  unit_value  quantity  total_cost
# id
# 5252  BWN 6"900RTJ ID142,88mm F44      1020.0      50.0     51000.0
# 5253            FORGING ROUND F44      2560.0      25.0     64000.0
# 5589         BRE 76,2MM HAST C276        44.5       1.6        71.2
# 5590                   TP1R 0,5mm       420.6       3.0      1261.8
# 5591      VAR 4.5X2X1.2X1000 A710        19.6       5.0        98.0

# %%
df_purchases["order_date"] = pd.to_datetime(df_purchases["order_date"])
df_purchases["delivery_date"] = pd.to_datetime(df_purchases["delivery_date"])

df_purchases.head(5)
# Out:
#      order_date delivery_date                   supplier_name  \
# id
# 5252 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5253 2013-05-16    2013-11-18              OFFICINE SANTAFEDE
# 5589 2013-09-02    2013-09-04           Aceros y Equipos S.L.
# 5590 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
# 5591 2013-09-03    2013-09-10  UTILES Y MAQUINAS INDUSTRIALES
#
#                  supply_reference  unit_value  quantity  total_cost
# id
# 5252  BWN 6"900RTJ ID142,88mm F44      1020.0      50.0     51000.0
# 5253            FORGING ROUND F44      2560.0      25.0     64000.0
# 5589         BRE 76,2MM HAST C276        44.5       1.6        71.2
# 5590                   TP1R 0,5mm       420.6       3.0      1261.8
# 5591      VAR 4.5X2X1.2X1000 A710        19.6       5.0        98.0
